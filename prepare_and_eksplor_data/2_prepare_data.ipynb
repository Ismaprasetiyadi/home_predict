# %% [markdown]
# # Library

# %%
import pandas as pd

# %% [markdown]
# # Data

# %%
dist_data_properti = pd.read_csv("/mnt/extended-home/ismaprasetiyadi/skripsi/data/data_rumah_dengan_jarak_fasilitas.csv")
dist_data_properti.head(5)
# Out:
#    Harga_Asli kecamatan  bedroom  bathrooms  jumlah_guest_toilet  \
# 0   385000000   Wonoayu        2          1                    1
# 1   540000000    Sedati        2          1                    1
# 2  1960000000     Candi        4          3                    3
# 3   950000000     Candi        3          2                    2
# 4   691000000  Sukodono        2          2                    2
#
#                                      list_facilities  \
# 0   Internet, Air, Tanpa perabotan, Halaman, Listrik
# 1  Garasi, AC, Kabel video, Air, Tanpa perabotan,...
# 2  Garasi, AC, Dapur lengkap, Tangki air, Listrik...
# 3         Garasi, Halaman, Internet, Tanpa perabotan
# 4  Garasi, Halaman, Tanpa perabotan, Internet, Li...
#
#                                       list_buildings  lantai  area_digunakan  \
# 0  Keamanan, Taman, Keamanan 24 jam, Area anak-an...       1              34
# 1  Keamanan, Gym, Taman, Rumah jaga, Keamanan 24 ...       1              32
# ...

# %%
road_data_properti = pd.read_csv("/mnt/extended-home/ismaprasetiyadi/skripsi/data/data_properti_sidoarjo_with_road_score.csv")
road_data_properti.head(5)
# Out:
#    Harga_Asli kecamatan  bedroom  bathrooms  jumlah_guest_toilet  \
# 0   385000000   Wonoayu        2          1                    1
# 1   540000000    Sedati        2          1                    1
# 2  1960000000     Candi        4          3                    3
# 3   950000000     Candi        3          2                    2
# 4   691000000  Sukodono        2          2                    2
#
#                                      list_facilities  \
# 0   Internet, Air, Tanpa perabotan, Halaman, Listrik
# 1  Garasi, AC, Kabel video, Air, Tanpa perabotan,...
# 2  Garasi, AC, Dapur lengkap, Tangki air, Listrik...
# 3         Garasi, Halaman, Internet, Tanpa perabotan
# 4  Garasi, Halaman, Tanpa perabotan, Internet, Li...
#
#                                       list_buildings  lantai  area_digunakan  \
# 0  Keamanan, Taman, Keamanan 24 jam, Area anak-an...       1              34
# 1  Keamanan, Gym, Taman, Rumah jaga, Keamanan 24 ...       1              32
# ...

# %%
dist_data_properti["road_score"] = road_data_properti["road_score"]
dist_data_properti.head(3)
# Out:
#    Harga_Asli kecamatan  bedroom  bathrooms  jumlah_guest_toilet  \
# 0   385000000   Wonoayu        2          1                    1
# 1   540000000    Sedati        2          1                    1
# 2  1960000000     Candi        4          3                    3
#
#                                      list_facilities  \
# 0   Internet, Air, Tanpa perabotan, Halaman, Listrik
# 1  Garasi, AC, Kabel video, Air, Tanpa perabotan,...
# 2  Garasi, AC, Dapur lengkap, Tangki air, Listrik...
#
#                                       list_buildings  lantai  area_digunakan  \
# 0  Keamanan, Taman, Keamanan 24 jam, Area anak-an...       1              34
# 1  Keamanan, Gym, Taman, Rumah jaga, Keamanan 24 ...       1              32
# 2  Area anak-anak, Rumah jaga, Taman, Keamanan 24...       3              72
#
#    luas_tanah  ...  dist_Fasilitas_Kesehatan  dist_Mall  dist_Supermarket  \
# 0          10  ...                  5.527251   9.865963          8.244602
# ...

# %%
dist_data_properti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Harga_Asli                1241 non-null   int64
#  1   kecamatan                 1241 non-null   object
#  2   bedroom                   1241 non-null   int64
#  3   bathrooms                 1241 non-null   int64
#  4   jumlah_guest_toilet       1241 non-null   int64
#  5   list_facilities           1241 non-null   object
#  6   list_buildings            1241 non-null   object
#  7   lantai                    1241 non-null   int64
#  8   area_digunakan            1241 non-null   int64
#  9   luas_tanah                1241 non-null   int64
#  10  latitude                  1241 non-null   float64
#  11  longitude                 1241 non-null   float64
#  12  dist_SD                   1239 non-null   float64
# ...

# %%
dist_data_properti["has_exit_tol"] = (~dist_data_properti["dist_Entry_Exit_Tol"].isna()).astype(int)

# %%
max_tol = dist_data_properti["dist_Entry_Exit_Tol"].max()
dist_data_properti["dist_Entry_Exit_Tol"] = dist_data_properti["dist_Entry_Exit_Tol"].fillna(max_tol*2)

# %%
dist_data_properti.info()
dist_data_properti.tail(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1241 entries, 0 to 1240
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Harga_Asli                1241 non-null   int64
#  1   kecamatan                 1241 non-null   object
#  2   bedroom                   1241 non-null   int64
#  3   bathrooms                 1241 non-null   int64
#  4   jumlah_guest_toilet       1241 non-null   int64
#  5   list_facilities           1241 non-null   object
#  6   list_buildings            1241 non-null   object
#  7   lantai                    1241 non-null   int64
#  8   area_digunakan            1241 non-null   int64
#  9   luas_tanah                1241 non-null   int64
#  10  latitude                  1241 non-null   float64
#  11  longitude                 1241 non-null   float64
#  12  dist_SD                   1239 non-null   float64
# ...

# %%
dist_data_properti[dist_data_properti.isna().any(axis=1)]
# Out:
#      Harga_Asli kecamatan  bedroom  bathrooms  jumlah_guest_toilet  \
# 14    850000000     Taman        3          2                    0
# 846  2680000000      Waru        4          2                    0
#
#                               list_facilities   list_buildings  lantai  \
# 14          Garasi, Tangki air, Wifi, AC, Air  Keamanan 24 jam       2
# 846  Internet, Tanpa perabotan, Dapur lengkap  Keamanan, Taman       1
#
#      area_digunakan  luas_tanah  ...  dist_Mall  dist_Supermarket  \
# 14               90          36  ...        NaN               NaN
# 846              90         112  ...        NaN               0.0
#
#      dist_Minimarket  dist_Stasiun  dist_Terminal  dist_Bandara  dist_Halte  \
# 14               NaN           NaN            NaN           NaN         NaN
# 846              NaN           NaN            NaN           NaN         NaN
#
#      dist_Entry_Exit_Tol  road_score  has_exit_tol
# 14             81.195014           5             0
# ...

# %%
merge_data = dist_data_properti.dropna()
merge_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1239 entries, 0 to 1240
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Harga_Asli                1239 non-null   int64
#  1   kecamatan                 1239 non-null   object
#  2   bedroom                   1239 non-null   int64
#  3   bathrooms                 1239 non-null   int64
#  4   jumlah_guest_toilet       1239 non-null   int64
#  5   list_facilities           1239 non-null   object
#  6   list_buildings            1239 non-null   object
#  7   lantai                    1239 non-null   int64
#  8   area_digunakan            1239 non-null   int64
#  9   luas_tanah                1239 non-null   int64
#  10  latitude                  1239 non-null   float64
#  11  longitude                 1239 non-null   float64
#  12  dist_SD                   1239 non-null   float64
#  13  dist_SMP                  1239 non-null   float64
# ...

# %%
merge_data.to_csv(
    "/mnt/extended-home/ismaprasetiyadi/skripsi/data/final_data.csv",
    index=False
)
